# %% [markdown]
# <p style='text-align: right;'> Sophie Huang<br>605195122<br>10/7/19 </p>

# %% [markdown]
# # Homework 1 - Optional Problem (2.13)

# %%
using Plots

# %%
x=0:10:100;

# %%
y=[70,76,84,91,97,102,107,110,112,114,115];

# %%
ps = scatter(x,y,xlim=(0,100),ylim=(60,120),legend=false,xlabel="specific weight (lb/ft^3)",ylabel="h (ft)")

# %%
using CurveFit
